# %%
import gzip
import json
import csv
import re
# with gzip.open(r"C:\Users\duphong.hua\Downloads\2024-06-20-09-33-19-a07057af-ea90-47b7-8a34-8b17341e2539.jsonl", mode="rt") as f:
#     data = [json.loads(line) for line in f]

# %%
def read_jsonl(file_path):
    data = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            json_obj = json.loads(line.strip())
            data.append(json_obj)
    return data

# %%
path = r"C:\Users\duphong.hua\Downloads\2024-06-20-09-33-19-a07057af-ea90-47b7-8a34-8b17341e2539.jsonl"
jsonfile = read_jsonl(path)

# %%
header = ['@severity',	'@service',	'@az',	'@idc',	'@message',	'@source',	'@category',	'@env',	'@timestamp',	'@cid',	'@host']
with open('output.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer = csv.DictWriter(csvfile, fieldnames=header)
    writer.writeheader()
    for i in jsonfile:
        # Create a DictWriter object
        # print(i.values())
        # # Write the rows
        writer.writerows([i])

# %%
object = []
for i in jsonfile[0:]:
    object.append(i['@message'].split(','))

# %%
def parse_log_entries(log_entries):
    data_dict = {}
    current_key = None
    multi_line_value = []

    for entry in log_entries:
        entry = entry.strip()
        if ': ' in entry:
            if current_key and multi_line_value:
                data_dict[current_key] = ' '.join(multi_line_value).strip()
                multi_line_value = []

            key, value = entry.split(': ', 1)
            key = key.strip()
            value = value.strip()
            
            if value.startswith('{') or value.startswith('['):
                current_key = key
                multi_line_value.append(value)
            else:
                data_dict[key] = value
                current_key = None
        elif current_key:
            multi_line_value.append(entry.strip())
    
    if current_key and multi_line_value:
        data_dict[current_key] = ' '.join(multi_line_value).strip()
    
    return data_dict

def remove_special_characters(value):
    # return re.sub(r'[^A-Za-z0-9\s]', '', value)
    # def remove_special_characters(value):
    return re.sub(r"[{\}]",'', value)

# %%
# cleaned_data = {key: remove_special_characters(str(object)) for key, value in parse_log_entries(object).items()}
with open('log_entries.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    # writer.writerow(remove_special_characters(parse_log_entries(object[0]).keys()))
    writer.writerow(['grayscale_toggle',	'distance',	'fee_config',	'unit_fee',	'pickdrop_fee',	'min_fee',	'hub_config_source',	'discount_rate',	'group_member_fee_list',	'fee_config',	'surge_rate',	'is_decoupled',	'shipping_fee',	'distance',	'shipping_fee_no_surge',	'final_shipping_fee',	'total_single_shipping_fee',	'hub_stack_shipping_fee',	'hub_calculate_details',	'dropoff_points',	'lng_lat_compare_precision',	'package_increase_original_fee_replace',	'unique_pickup_points_toggle',	'original_dropoff_points',	'hub_stack_fee',	'pickup_points',	'package_decrease_original_fee_replace',	'discount_fee',	'unique_dropoff_points_toggle',	'original_delivery_info',	'delivery_order_ids',	'hub_extra_fee',])
    for i in object:
    # Write the header
    # Write the row of data
        writer.writerow((parse_log_entries(i).values()))

print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %%
df
# Out:
#         Unnamed: 0  grayscale_toggle  distance            fee_config  \
# 0                0                 1    3465.3  {'is_round_up': True
# 1                1                 1    2450.1  {'is_round_up': True
# 2                2                 1    1934.4  {'is_round_up': True
# 3                3                 1    1584.4  {'is_round_up': True
# 4                4                 1    2866.0  {'is_round_up': True
# ...            ...               ...       ...                   ...
# 212082      212082                 1    5264.5  {'is_round_up': True
# 212083      212083                 1    5280.3  {'is_round_up': True
# 212084      212084                 1    5264.5  {'is_round_up': True
# 212085      212085                 1    5280.3  {'is_round_up': True
# 212086      212086                 1    2784.0  {'is_round_up': True
#
#         unit_fee  pickdrop_fee  min_fee hub_config_source discount_rate  \
# 0              0          1000    13500           'admin'           0.7
# 1              0          1000    13500           'admin'           0.7
# 2              0          1000    13500           'admin'           0.7
# 3              0          1000    13500           'admin'           0.7
# 4              0          1000    13500           'admin'           0.7
# ...          ...           ...      ...               ...           ...
# 212082         0          1000    13500           'admin'           0.7
# 212083         0          1000    13500           'admin'           0.7
# 212084         0          1000    13500           'admin'           0.7
# 212085         0          1000    13500           'admin'           0.7
# 212086         0          1000    13500           'admin'           0.7
#
#                      group_member_fee_list  ... unique_pickup_points_toggle  \
# 0       [{'shipping_fee_no_surge': 13500.0  ...                       False
# 1       [{'shipping_fee_no_surge': 13500.0  ...                       False
# 2       [{'shipping_fee_no_surge': 13500.0  ...                       False
# 3       [{'shipping_fee_no_surge': 13500.0  ...                       False
# 4       [{'shipping_fee_no_surge': 13500.0  ...                       False
# ...                                    ...  ...                         ...
# 212082  [{'shipping_fee_no_surge': 13500.0  ...                       False
# 212083  [{'shipping_fee_no_surge': 13500.0  ...                       False
# 212084  [{'shipping_fee_no_surge': 13500.0  ...                       False
# 212085  [{'shipping_fee_no_surge': 13500.0  ...                       False
# 212086  [{'shipping_fee_no_surge': 13500.0  ...                       False
#
#         original_dropoff_points hub_stack_fee  pickup_points  \
# 0                             2     13500.000              2
# 1                             2     13500.000              2
# 2                             2     13500.000              2
# 3                             2     13500.000              2
# 4                             2     13500.000              2
# ...                         ...           ...            ...
# 212082                        2     19741.875              2
# 212083                        2     19801.125              2
# 212084                        2     19741.875              2
# 212085                        2     19801.125              2
# 212086                        2     13500.000              2
#
#         package_decrease_original_fee_replace  discount_fee  \
# 0                                       False       18900.0
# 1                                       False       18900.0
# 2                                       False       18900.0
# 3                                       False       18900.0
# 4                                       False       18900.0
# ...                                       ...           ...
# 212082                                  False       18900.0
# 212083                                  False       18900.0
# 212084                                  False       18900.0
# 212085                                  False       18900.0
# 212086                                  False       18900.0
#
#         unique_dropoff_points_toggle    original_delivery_info  \
# 0                              False  {'shipping_fee': 27000.0
# 1                              False  {'shipping_fee': 27000.0
# 2                              False  {'shipping_fee': 13500.0
# 3                              False  {'shipping_fee': 27000.0
# 4                              False  {'shipping_fee': 27000.0
# ...                              ...                       ...
# 212082                         False  {'shipping_fee': 13500.0
# 212083                         False  {'shipping_fee': 13500.0
# 212084                         False  {'shipping_fee': 13500.0
# 212085                         False  {'shipping_fee': 13500.0
# 212086                         False  {'shipping_fee': 13500.0
#
#          delivery_order_ids hub_extra_fee
# 0       513148471 513191772          2000
# 1       513072698 513073377          2000
# 2                 513343236          2000
# 3       513327728 513333212          2000
# 4       513052959 513052961          2000
# ...                     ...           ...
# 212082            513062036          2000
# 212083            513062495          2000
# 212084            513062036          2000
# 212085            513062495          2000
# 212086            513062554          2000
#
# [212087 rows x 33 columns]

# %%
path = r'C:\Users\duphong.hua\Downloads\log_entries.csv'
import pandas as pd 
df = pd.read_csv(path)
# df
df['discount_rate'] = [remove_special_characters(str(i)) for i in df['discount_rate'].to_list()]
df['hub_extra_fee'] = [remove_special_characters(str(i)) for i in df['hub_extra_fee'].to_list()]
df['delivery_order_ids'] = [remove_special_characters(i).replace(' ',',') for i in df['delivery_order_ids'].to_list()]
# df['discount_rate'] = [str(i).replace('}','') for i in df['discount_rate'].to_list()]

# %%
df.to_csv('log_entries.csv')
# [str(i).replace('}','') for i in df['hub_extra_fee'].to_list()]

# %%
filter = df[['delivery_order_ids','hub_extra_fee','final_shipping_fee','total_single_shipping_fee','hub_stack_shipping_fee','hub_stack_fee']]
# a = '[513148471 513191772]}'
# remove_special_characters(a)		
# a
filter.to_csv('final_file.csv',encoding='utf-8-sig',index=False)

# %%
filter
# Out:
#            delivery_order_ids hub_extra_fee  final_shipping_fee  \
# 0       [513148471,513191772]          2000               27000
# 1       [513072698,513073377]          2000               27000
# 2                 [513343236]          2000               27000
# 3       [513327728,513333212]          2000               27000
# 4       [513052959,513052961]          2000               27000
# ...                       ...           ...                 ...
# 212082            [513062036]          2000               27000
# 212083            [513062495]          2000               27000
# 212084            [513062036]          2000               27000
# 212085            [513062495]          2000               27000
# 212086            [513062554]          2000               27000
#
#         total_single_shipping_fee  hub_stack_shipping_fee  hub_stack_fee
# 0                           27000                 20900.0      13500.000
# 1                           27000                 20900.0      13500.000
# 2                           27000                 20900.0      13500.000
# 3                           27000                 20900.0      13500.000
# 4                           27000                 20900.0      13500.000
# ...                           ...                     ...            ...
# 212082                      27000                 21742.0      19741.875
# 212083                      27000                 21802.0      19801.125
# 212084                      27000                 21742.0      19741.875
# 212085                      27000                 21802.0      19801.125
# 212086                      27000                 20900.0      13500.000
#
# [212087 rows x 6 columns]
