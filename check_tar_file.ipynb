# %%
import gzip
import json
import csv
import re
# with gzip.open(r"C:\Users\duphong.hua\Downloads\2024-06-20-09-33-19-a07057af-ea90-47b7-8a34-8b17341e2539.jsonl", mode="rt") as f:
#     data = [json.loads(line) for line in f]

# %%
def read_jsonl(file_path):
    data = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            json_obj = json.loads(line.strip())
            data.append(json_obj)
    return data

# %%
path = r"C:\Users\duphong.hua\Downloads\shadow_test.jsonl"
jsonfile = read_jsonl(path)[:600000]

# %%
# len(jsonfile[500000:])
jsonfile
# Out:
# [{'@timestamp': 1719318986941,
#   '@severity': 'INFO',
#   '@service': 'shippingfee-api',
#   '@cid': 'vn',
#   '@message': "2024-06-25 19:36:26.941|INFO|normal-d77cd91d6a054d8693a5366c0accb678|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2375.6, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1800}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1000}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2375.6, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516397459]}, 'hub_extra_fee': 2000}",
#   '@host': '10.84.20.194',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@idc': '',
#   '@env': 'live',
#   '@category': 'info.log',
#   '@az': 'ap-vn-2-general-a'},
#  {'@category': 'info.log',
#   '@message': "2024-06-26 21:49:26.358|INFO|normal-3807c3b7817248489ff70a8e2d73f0a7|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2840.0, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2500}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 900}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2840.0, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516905430]}, 'hub_extra_fee': 2000}",
#   '@env': 'live',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@cid': 'vn',
#   '@host': '10.84.19.158',
#   '@az': 'ap-vn-2-general-a',
#   '@idc': '',
#   '@timestamp': 1719413366358,
#   '@severity': 'INFO',
#   '@service': 'shippingfee-api'},
#  {'@env': 'live',
#   '@host': '10.84.19.158',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@severity': 'INFO',
#   '@cid': 'vn',
#   '@service': 'shippingfee-api',
#   '@idc': '',
#   '@timestamp': 1719413366908,
#   '@az': 'ap-vn-2-general-a',
#   '@message': "2024-06-26 21:49:26.908|INFO|normal-1c6028f331d34ffeba415dde6e6abff9|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3794.0, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1400}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2900}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 14227.5, 'distance': 3794.0, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516903149]}, 'hub_extra_fee': 2000}"},
#  {'@severity': 'INFO',
#   '@cid': 'vn',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@message': "2024-06-25 19:36:30.200|INFO|normal-e87980d8ae3644349d5bece2a802dd09|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 5974.2, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3500}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3200}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 24404.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 22403.25, 'distance': 5974.2, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516398043]}, 'hub_extra_fee': 2000}",
#   '@timestamp': 1719318990200,
#   '@service': 'shippingfee-api',
#   '@az': 'ap-vn-2-general-a',
#   '@idc': '',
#   '@env': 'live',
#   '@host': '10.84.18.67'},
#  {'@timestamp': 1719318990232,
#   '@env': 'live',
#   '@idc': '',
#   '@cid': 'vn',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@message': "2024-06-25 19:36:30.232|INFO|normal-926b2698d11b4998bb349e5241285846|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2906.8, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2100}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2600}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2906.8, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516391407, 516394276]}, 'hub_extra_fee': 2000}",
#   '@severity': 'INFO',
#   '@service': 'shippingfee-api',
#   '@host': '10.84.18.67',
#   '@category': 'info.log'},
#  {'@message': "2024-06-25 19:36:30.089|INFO|normal-75cbaf5875e14a70bd13b7c62f7ae86b|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3926.5, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1200}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2900}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 14724.375, 'distance': 3926.5, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516389044, 516392246]}, 'hub_extra_fee': 2000}",
#   '@timestamp': 1719318990089,
#   '@service': 'shippingfee-api',
#   '@cid': 'vn',
#   '@env': 'live',
#   '@host': '10.84.18.94',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@idc': '',
#   '@severity': 'INFO'},
#  {'@timestamp': 1719318990269,
#   '@service': 'shippingfee-api',
#   '@az': 'ap-vn-2-general-a',
#   '@env': 'live',
#   '@idc': '',
#   '@cid': 'vn',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@message': "2024-06-25 19:36:30.269|INFO|normal-174c87cdd4dd4c8b8ae1e1d6e563276f|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 4761.7, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1300}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3500}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 17856.375, 'distance': 4761.7, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516393035, 516394232]}, 'hub_extra_fee': 2000}",
#   '@severity': 'INFO',
#   '@host': '10.84.18.94'},
#  {'@timestamp': 1719413367072,
#   '@message': "2024-06-26 21:49:27.072|INFO|normal-0d663b3d53a8410d80b756c3d1853ad1|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3264.3, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1900}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1500}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3264.3, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516901625, 516904454]}, 'hub_extra_fee': 2000}",
#   '@az': 'ap-vn-2-general-a',
#   '@service': 'shippingfee-api',
#   '@env': 'live',
#   '@severity': 'INFO',
#   '@host': '10.84.18.94',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@idc': '',
#   '@cid': 'vn',
#   '@category': 'info.log'},
#  {'@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@idc': '',
#   '@severity': 'INFO',
#   '@service': 'shippingfee-api',
#   '@message': "2024-06-26 21:49:27.120|INFO|normal-2d2a3ca939f7427da2be45796c7e61b9|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 6117.4, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3600}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3100}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 24941.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 22940.25, 'distance': 6117.4, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516900832, 516902409]}, 'hub_extra_fee': 2000}",
#   '@cid': 'vn',
#   '@host': '10.84.18.94',
#   '@env': 'live',
#   '@category': 'info.log',
#   '@timestamp': 1719413367120},
#  {'@host': '10.84.19.17',
#   '@category': 'info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@cid': 'vn',
#   '@env': 'live',
#   '@message': "2024-06-26 21:49:28.711|INFO|normal-d521ac7c03b949199c925f1deef84d0c|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 4643.89, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2300}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3000}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 17414.5875, 'distance': 4643.89, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516904740]}, 'hub_extra_fee': 2000}",
#   '@service': 'shippingfee-api',
#   '@timestamp': 1719413368711,
#   '@severity': 'INFO',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@idc': ''},
#  {'@severity': 'INFO',
#   '@timestamp': 1719399667876,
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@message': "2024-06-26 18:01:07.876|INFO|normal-29968cf681fc4b629164814386cb5cc1|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3179.4, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1900}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2300}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3179.4, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516805744]}, 'hub_extra_fee': 2000}",
#   '@cid': 'vn',
#   '@az': 'ap-vn-2-general-a',
#   '@idc': '',
#   '@service': 'shippingfee-api',
#   '@env': 'live',
#   '@host': '10.84.18.94',
#   '@category': 'info.log'},
#  {'@host': '10.84.18.100',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@env': 'live',
#   '@service': 'shippingfee-api',
#   '@message': "2024-06-26 21:49:29.075|INFO|normal-056a17f5698049a6b44a66f126f6a083|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 1254.0, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1000}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1200}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 1254.0, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516901759, 516903354]}, 'hub_extra_fee': 2000}",
#   '@timestamp': 1719413369075,
#   '@severity': 'INFO',
#   '@idc': '',
#   '@cid': 'vn',
#   '@category': 'info.log'},
#  {'@severity': 'INFO',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@idc': '',
#   '@cid': 'vn',
#   '@host': '10.84.18.104',
#   '@timestamp': 1719413368852,
#   '@message': "2024-06-26 21:49:28.852|INFO|normal-ec4c3495afbd4dc2b26ebc2e0bd882ca|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3116.1, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1400}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2200}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3116.1, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516904226]}, 'hub_extra_fee': 2000}",
#   '@service': 'shippingfee-api',
#   '@env': 'live',
#   '@category': 'info.log',
#   '@az': 'ap-vn-2-general-a'},
#  {'@cid': 'vn',
#   '@severity': 'INFO',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@idc': '',
#   '@message': "2024-06-26 11:31:19.087|INFO|normal-545e6439a04b4da6a4f0d0fd10626d65|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3189.39, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2900}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1800}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3189.39, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516601170, 516605624]}, 'hub_extra_fee': 2000}",
#   '@timestamp': 1719376279087,
#   '@env': 'live',
#   '@host': '10.84.18.100',
#   '@category': 'info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@service': 'shippingfee-api'},
#  {'@az': 'ap-vn-2-general-a',
#   '@idc': '',
#   '@timestamp': 1719376279289,
#   '@service': 'shippingfee-api',
#   '@host': '10.84.18.94',
#   '@cid': 'vn',
#   '@message': "2024-06-26 11:31:19.289|INFO|normal-94dcfa77a7a44e36b11f1f4770049f51|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3521.9, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1900}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2700}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3521.9, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516597201]}, 'hub_extra_fee': 2000}",
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@severity': 'INFO',
#   '@env': 'live'},
#  {'@severity': 'INFO',
#   '@env': 'live',
#   '@host': '10.84.19.17',
#   '@category': 'info.log',
#   '@message': "2024-06-26 11:31:20.077|INFO|normal-05ead3374e90478ca5494e4becbc553b|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 4840.6, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1900}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3400}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 18152.25, 'distance': 4840.6, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516573748, 516601643]}, 'hub_extra_fee': 2000}",
#   '@idc': '',
#   '@timestamp': 1719376280077,
#   '@service': 'shippingfee-api',
#   '@az': 'ap-vn-2-general-a',
#   '@cid': 'vn',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log'},
#  {'@host': '10.84.19.17',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@idc': '',
#   '@severity': 'INFO',
#   '@az': 'ap-vn-2-general-a',
#   '@message': "2024-06-26 11:31:20.232|INFO|normal-77c9f1e2d5d14d189438cb2648e98ea0|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2021.6, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1800}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1200}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2021.6, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516605532]}, 'hub_extra_fee': 2000}",
#   '@cid': 'vn',
#   '@env': 'live',
#   '@timestamp': 1719376280232,
#   '@service': 'shippingfee-api'},
#  {'@timestamp': 1719376280344,
#   '@service': 'shippingfee-api',
#   '@az': 'ap-vn-2-general-a',
#   '@env': 'live',
#   '@host': '10.84.19.158',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@severity': 'INFO',
#   '@message': "2024-06-26 11:31:20.344|INFO|normal-05a62bce6c1f4a588679e72aae8fcfd2|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2216.3, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1500}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1000}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2216.3, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516604835]}, 'hub_extra_fee': 2000}",
#   '@cid': 'vn',
#   '@idc': ''},
#  {'@message': "2024-06-26 11:31:20.347|INFO|normal-05a62bce6c1f4a588679e72aae8fcfd2|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2485.5, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1500}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1300}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2485.5, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516598942]}, 'hub_extra_fee': 2000}",
#   '@cid': 'vn',
#   '@az': 'ap-vn-2-general-a',
#   '@timestamp': 1719376280347,
#   '@severity': 'INFO',
#   '@service': 'shippingfee-api',
#   '@idc': '',
#   '@host': '10.84.19.158',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@env': 'live'},
#  {'@cid': 'vn',
#   '@host': '10.84.18.67',
#   '@idc': '',
#   '@message': "2024-06-26 11:31:20.362|INFO|normal-05a62bce6c1f4a588679e72aae8fcfd2|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 5113.0, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2900}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2700}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 21174.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 19173.75, 'distance': 5113.0, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516600483]}, 'hub_extra_fee': 2000}",
#   '@timestamp': 1719376280362,
#   '@severity': 'INFO',
#   '@az': 'ap-vn-2-general-a',
#   '@category': 'info.log',
#   '@service': 'shippingfee-api',
#   '@env': 'live',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log'},
#  {'@host': '10.84.18.157',
#   '@category': 'info.log',
#   '@idc': '',
#   '@service': 'shippingfee-api',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@severity': 'INFO',
#   '@message': "2024-06-26 11:31:17.293|INFO|normal-1f40e1453d764101add273b108f87211|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 1870.3, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 200}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 700}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 1870.3, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516588926, 516600100]}, 'hub_extra_fee': 2000}",
#   '@timestamp': 1719376277293,
#   '@cid': 'vn',
#   '@env': 'live'},
#  {'@message': "2024-06-26 11:31:17.321|INFO|normal-05a62bce6c1f4a588679e72aae8fcfd2|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2445.8, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 900}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1600}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2445.8, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516600922]}, 'hub_extra_fee': 2000}",
#   '@cid': 'vn',
#   '@env': 'live',
#   '@host': '10.84.18.157',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@timestamp': 1719376277321,
#   '@severity': 'INFO',
#   '@service': 'shippingfee-api',
#   '@idc': ''},
#  {'@timestamp': 1719376277328,
#   '@service': 'shippingfee-api',
#   '@host': '10.84.18.157',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@cid': 'vn',
#   '@category': 'info.log',
#   '@message': "2024-06-26 11:31:17.328|INFO|normal-05a62bce6c1f4a588679e72aae8fcfd2|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 1636.1, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1200}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 900}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 1636.1, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516601174]}, 'hub_extra_fee': 2000}",
#   '@severity': 'INFO',
#   '@env': 'live',
#   '@az': 'ap-vn-2-general-a',
#   '@idc': ''},
#  {'@message': "2024-06-26 11:31:17.335|INFO|normal-05a62bce6c1f4a588679e72aae8fcfd2|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 1073.9, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1000}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 300}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 1073.9, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516603814]}, 'hub_extra_fee': 2000}",
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@severity': 'INFO',
#   '@cid': 'vn',
#   '@timestamp': 1719376277335,
#   '@service': 'shippingfee-api',
#   '@category': 'info.log',
#   '@env': 'live',
#   '@host': '10.84.18.157',
#   '@idc': ''},
#  {'@category': 'info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@cid': 'vn',
#   '@severity': 'INFO',
#   '@env': 'live',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@message': "2024-06-26 11:31:20.326|INFO|normal-05a62bce6c1f4a588679e72aae8fcfd2|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3316.5, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1400}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2300}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3316.5, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516604913]}, 'hub_extra_fee': 2000}",
#   '@service': 'shippingfee-api',
#   '@timestamp': 1719376280326,
#   '@host': '10.84.18.195',
#   '@idc': ''},
#  {'@cid': 'vn',
#   '@env': 'live',
#   '@message': "2024-06-26 11:31:20.088|INFO|normal-e0220bfbf01948a9879a85cee5bcd40e|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 6805.6, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3300}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3800}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 27000.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 25521.0, 'distance': 6805.6, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516600275, 516604305]}, 'hub_extra_fee': 2000}",
#   '@severity': 'INFO',
#   '@host': '10.84.18.94',
#   '@category': 'info.log',
#   '@idc': '',
#   '@timestamp': 1719376280088,
#   '@service': 'shippingfee-api',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@az': 'ap-vn-2-general-a'},
#  {'@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@severity': 'INFO',
#   '@env': 'live',
#   '@timestamp': 1719376280437,
#   '@service': 'shippingfee-api',
#   '@cid': 'vn',
#   '@host': '10.84.19.158',
#   '@idc': '',
#   '@message': "2024-06-26 11:31:20.437|INFO|normal-0029addac87f4ed6a4eb90f9a1dd3aef|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3078.4, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2500}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2000}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3078.4, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516594813, 516595834]}, 'hub_extra_fee': 2000}",
#   '@category': 'info.log'},
#  {'@severity': 'INFO',
#   '@service': 'shippingfee-api',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@cid': 'vn',
#   '@env': 'live',
#   '@idc': '',
#   '@message': "2024-06-26 11:31:18.053|INFO|normal-cb6d961b90084435a1033fa4ed27cf84|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2969.7, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2300}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1100}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2969.7, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516593055, 516596233]}, 'hub_extra_fee': 2000}",
#   '@host': '10.84.18.157',
#   '@category': 'info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@timestamp': 1719376278053},
#  {'@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
# ...
#   '@timestamp': 1719375608132,
#   '@host': '10.84.18.100',
#   '@az': 'ap-vn-2-general-a',
#   '@env': 'live',
#   '@service': 'shippingfee-api',
#   '@cid': 'vn',
#   '@severity': 'INFO',
#   '@category': 'info.log',
#   '@idc': '',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log'},
#  {'@message': "2024-06-26 11:29:21.244|INFO|normal-364f888d36b54541ae403e68fb6eecb3|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 1358.2, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 900}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 900}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 1358.2, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516595870]}, 'hub_extra_fee': 2000}",
#   '@service': 'shippingfee-api',
#   '@category': 'info.log',
#   '@idc': '',
#   '@timestamp': 1719376161244,
#   '@severity': 'INFO',
#   '@cid': 'vn',
#   '@env': 'live',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@host': '10.84.18.100',
#   '@az': 'ap-vn-2-general-a'},
#  {'@env': 'live',
#   '@category': 'info.log',
#   '@idc': '',
#   '@message': "2024-06-26 09:19:21.077|INFO|normal-e3f6989dacd1457c83ded886587926ab|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2865.2, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1300}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1600}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2865.2, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516516442, 516521962]}, 'hub_extra_fee': 2000}",
#   '@timestamp': 1719368361077,
#   '@severity': 'INFO',
#   '@service': 'shippingfee-api',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@host': '10.84.18.104',
#   '@az': 'ap-vn-2-general-a',
#   '@cid': 'vn'},
#  {'@env': 'live',
#   '@message': "2024-06-26 11:20:08.105|INFO|normal-f885ffb811884bd8858295c5a51e8ab7|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3407.7, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3200}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 400}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3407.7, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516574195, 516577494]}, 'hub_extra_fee': 2000}",
#   '@service': 'shippingfee-api',
#   '@severity': 'INFO',
#   '@cid': 'vn',
#   '@host': '10.84.18.67',
#   '@category': 'info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@timestamp': 1719375608105,
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@idc': ''},
#  {'@severity': 'INFO',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@timestamp': 1719375608239,
#   '@az': 'ap-vn-2-general-a',
#   '@message': "2024-06-26 11:20:08.239|INFO|normal-2614db12408c4a42928a43376aebfd2c|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 4371.3, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1300}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 3200}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 16392.375, 'distance': 4371.3, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516570871, 516574803]}, 'hub_extra_fee': 2000}",
#   '@host': '10.84.18.67',
#   '@category': 'info.log',
#   '@idc': '',
#   '@env': 'live',
#   '@service': 'shippingfee-api',
#   '@cid': 'vn'},
#  {'@service': 'shippingfee-api',
#   '@category': 'info.log',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@message': "2024-06-26 11:20:08.406|INFO|normal-fd63edf3c52145079d1e98c10e33d8a0|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3208.7, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2000}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1700}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3208.7, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516591707]}, 'hub_extra_fee': 2000}",
#   '@timestamp': 1719375608406,
#   '@severity': 'INFO',
#   '@cid': 'vn',
#   '@env': 'live',
#   '@host': '10.84.18.67',
#   '@idc': ''},
#  {'@timestamp': 1719398965124,
#   '@cid': 'vn',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@env': 'live',
#   '@az': 'ap-vn-2-general-a',
#   '@severity': 'INFO',
#   '@category': 'info.log',
#   '@message': "2024-06-26 17:49:25.124|INFO|normal-16ccb63486e245e09d52225939e175eb|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 2577.29, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1800}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1300}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 2577.29, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516792379, 516803300]}, 'hub_extra_fee': 2000}",
#   '@service': 'shippingfee-api',
#   '@host': '10.84.19.17',
#   '@idc': ''},
#  {'@timestamp': 1719376161758,
#   '@cid': 'vn',
#   '@host': '10.84.19.17',
#   '@az': 'ap-vn-2-general-a',
#   '@service': 'shippingfee-api',
#   '@severity': 'INFO',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@message': "2024-06-26 11:29:21.758|INFO|normal-4156640af72a48cebdf2049b009171c5|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3219.7, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1800}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1900}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3219.7, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516596861]}, 'hub_extra_fee': 2000}",
#   '@env': 'live',
#   '@category': 'info.log',
#   '@idc': ''},
#  {'@timestamp': 1719376161956,
#   '@env': 'live',
#   '@az': 'ap-vn-2-general-a',
#   '@service': 'shippingfee-api',
#   '@severity': 'INFO',
#   '@message': "2024-06-26 11:29:21.956|INFO|normal-76663eb295d64a40960c93211a3d01a2|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 3430.7, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1400}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2600}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 13500, 'distance': 3430.7, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 13500.0, 'delivery_order_ids': [516602557]}, 'hub_extra_fee': 2000}",
#   '@cid': 'vn',
#   '@host': '10.84.18.100',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@category': 'info.log',
#   '@idc': ''},
#  {'@timestamp': 1719302433075,
#   '@service': 'shippingfee-api',
#   '@host': '10.84.18.100',
#   '@category': 'info.log',
#   '@az': 'ap-vn-2-general-a',
#   '@idc': '',
#   '@source': '/data/log/food-vn-all/live/shippingfee-api/logs/info.log',
#   '@message': "2024-06-25 15:00:33.075|INFO|normal-68b9bc8914f642a0b9a3f3f39c924f6c|_calculate_hub_shippingfee done, grayscale_toggle: 1, distance: 4048.8, fee_config: {'is_round_up': True, 'unit_fee': 3750, 'pickdrop_fee': 1000, 'min_fee': 13500, 'hub_config_source': 'admin', 'discount_rate': 0.7}, group_member_fee_list: [{'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 2900}, {'shipping_fee_no_surge': 13500.0, 'fee_config': {'is_round_up': True, 'hub_config_source': 'admin', 'surge_rate': 1.0, 'min_fee': 13500, 'unit_fee': 0, 'is_decoupled': True}, 'shipping_fee': 13500, 'distance': 1200}], final_shipping_fee: 27000, total_single_shipping_fee: 27000, hub_stack_shipping_fee: 20900.0, hub_calculate_details: {'original_pickup_points': 2, 'dropoff_points': 2, 'lng_lat_compare_precision': -1, 'package_increase_original_fee_replace': False, 'unique_pickup_points_toggle': False, 'original_dropoff_points': 2, 'hub_stack_fee': 15183.0, 'distance': 4048.8, 'pickup_points': 2, 'package_decrease_original_fee_replace': False, 'discount_fee': 18900.0, 'unique_dropoff_points_toggle': False, 'original_delivery_info': {'shipping_fee': 27000.0, 'delivery_order_ids': [516264402, 516265958]}, 'hub_extra_fee': 2000}",
#   '@cid': 'vn',
#   '@env': 'live',
#   '@severity': 'INFO'},
#  ...]

# %%
header = ['@severity',	'@service',	'@az',	'@idc',	'@message',	'@source',	'@category',	'@env',	'@timestamp',	'@cid',	'@host']
with open(r'C:\Users\duphong.hua\Downloads\output_1.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer = csv.DictWriter(csvfile, fieldnames=header)
    writer.writeheader()
    for i in jsonfile:
        # Create a DictWriter object
        # print(i.values())
        # # Write the rows
        writer.writerows([i])

# %%
data_message = []
for i in jsonfile:
    data_message.append([i['@timestamp'],i['@message'].split(',')])
    # data_message.update({i['@timestamp']:i['@message'].split(',')})
    # data_message.append(i['@message'].split(','))

# %%
data_message[0]
# Out:
# [1719318986941,
#  ['2024-06-25 19:36:26.941|INFO|normal-d77cd91d6a054d8693a5366c0accb678|_calculate_hub_shippingfee done',
#   ' grayscale_toggle: 1',
#   ' distance: 2375.6',
#   " fee_config: {'is_round_up': True",
#   " 'unit_fee': 3750",
#   " 'pickdrop_fee': 1000",
#   " 'min_fee': 13500",
#   " 'hub_config_source': 'admin'",
#   " 'discount_rate': 0.7}",
#   " group_member_fee_list: [{'shipping_fee_no_surge': 13500.0",
#   " 'fee_config': {'is_round_up': True",
#   " 'hub_config_source': 'admin'",
#   " 'surge_rate': 1.0",
#   " 'min_fee': 13500",
#   " 'unit_fee': 0",
#   " 'is_decoupled': True}",
#   " 'shipping_fee': 13500",
#   " 'distance': 1800}",
#   " {'shipping_fee_no_surge': 13500.0",
#   " 'fee_config': {'is_round_up': True",
#   " 'hub_config_source': 'admin'",
#   " 'surge_rate': 1.0",
#   " 'min_fee': 13500",
#   " 'unit_fee': 0",
#   " 'is_decoupled': True}",
#   " 'shipping_fee': 13500",
#   " 'distance': 1000}]",
#   ' final_shipping_fee: 27000',
#   ' total_single_shipping_fee: 27000',
#   ' hub_stack_shipping_fee: 20900.0',
#   " hub_calculate_details: {'original_pickup_points': 2",
#   " 'dropoff_points': 2",
#   " 'lng_lat_compare_precision': -1",
#   " 'package_increase_original_fee_replace': False",
#   " 'unique_pickup_points_toggle': False",
#   " 'original_dropoff_points': 2",
#   " 'hub_stack_fee': 13500",
#   " 'distance': 2375.6",
#   " 'pickup_points': 2",
#   " 'package_decrease_original_fee_replace': False",
#   " 'discount_fee': 18900.0",
#   " 'unique_dropoff_points_toggle': False",
#   " 'original_delivery_info': {'shipping_fee': 13500.0",
#   " 'delivery_order_ids': [516397459]}",
#   " 'hub_extra_fee': 2000}"]]

# %%
def parse_log_entries(log_entries):
    data_dict = {}
    current_key = None
    multi_line_value = []

    for entry in log_entries:
        entry = entry.strip()
        if ': ' in entry:
            if current_key and multi_line_value:
                data_dict[current_key] = ' '.join(multi_line_value).strip()
                multi_line_value = []

            key, value = entry.split(': ', 1)
            key = key.strip()
            value = value.strip()
            
            if value.startswith('{') or value.startswith('['):
                current_key = key
                multi_line_value.append(value)
            else:
                data_dict[key] = value
                current_key = None
        elif current_key:
            multi_line_value.append(entry.strip())
    
    if current_key and multi_line_value:
        data_dict[current_key] = ' '.join(multi_line_value).strip()
    
    return data_dict

def remove_special_characters(value):
    # return re.sub(r'[^A-Za-z0-9\s]', '', value)
    # def remove_special_characters(value):
    return re.sub(r"[{\}]",'', value)

# %%
# cleaned_data = {key: remove_special_characters(str(object)) for key, value in parse_log_entries(object).items()}
with open(r'C:\Users\duphong.hua\Downloads\log_entries_1.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    # writer.writerow(remove_special_characters(parse_log_entries(object[0]).keys()))
    writer.writerow(['timestamp','grayscale_toggle',	'distance',	'fee_config',	'unit_fee',	'pickdrop_fee',	'min_fee',	'hub_config_source',	'discount_rate',	'group_member_fee_list',	'fee_config',	'surge_rate',	'is_decoupled',	'shipping_fee',	'distance',	'shipping_fee_no_surge',	'final_shipping_fee',	'total_single_shipping_fee',	'hub_stack_shipping_fee',	'hub_calculate_details',	'dropoff_points',	'lng_lat_compare_precision',	'package_increase_original_fee_replace',	'unique_pickup_points_toggle',	'original_dropoff_points',	'hub_stack_fee',	'pickup_points',	'package_decrease_original_fee_replace',	'discount_fee',	'unique_dropoff_points_toggle',	'original_delivery_info',	'delivery_order_ids',	'hub_extra_fee',])
    r = 0
    for i in data_message:
        # writer.writerow((i[0],parse_log_entries(i[-1]).values()))
        writer.writerow([i[0]] + list(parse_log_entries(i[-1]).values()))
        # r += 1
        # if r > 2:
        #     break
print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %%
path = r'C:\Users\duphong.hua\Downloads\log_entries_1.csv'
import pandas as pd 
df = pd.read_csv(path)
# df['timestamp']
df['discount_rate'] = [remove_special_characters(str(i)) for i in df['discount_rate'].to_list()]
df['hub_extra_fee'] = [remove_special_characters(str(i)) for i in df['hub_extra_fee'].to_list()]
df['delivery_order_ids'] = [remove_special_characters(i).replace(' ',',') for i in df['delivery_order_ids'].to_list()]
# df['discount_rate'] = [str(i).replace('}','') for i in df['discount_rate'].to_list()]

# %%
# df.to_csv('log_entries.csv')
# [str(i).replace('}','') for i in df['hub_extra_fee'].to_list()]

# %%
filter = df[['timestamp','delivery_order_ids','hub_extra_fee','final_shipping_fee','total_single_shipping_fee','hub_stack_shipping_fee','hub_stack_fee']]
# a = '[513148471 513191772]}'
# remove_special_characters(a)		
# a
filter.to_csv(r'C:\Users\duphong.hua\Downloads\final_file_1.csv',encoding='utf-8-sig',index=False)

# %%
df
# Out:
#             timestamp  grayscale_toggle  distance            fee_config  \
# 0       1719318986941                 1   2375.60  {'is_round_up': True
# 1       1719413366358                 1   2840.00  {'is_round_up': True
# 2       1719413366908                 1   3794.00  {'is_round_up': True
# 3       1719318990200                 1   5974.20  {'is_round_up': True
# 4       1719318990232                 1   2906.80  {'is_round_up': True
# ...               ...               ...       ...                   ...
# 599995  1719199041070                 1   4193.90  {'is_round_up': True
# 599996  1719199041167                 1   3459.00  {'is_round_up': True
# 599997  1719199042079                 1   4755.00  {'is_round_up': True
# 599998  1719216501638                 1   2486.19  {'is_round_up': True
# 599999  1719113858503                 1   2391.80  {'is_round_up': True
#
#         unit_fee  pickdrop_fee  min_fee hub_config_source discount_rate  \
# 0              0          1000    13500           'admin'           0.7
# 1              0          1000    13500           'admin'           0.7
# 2              0          1000    13500           'admin'           0.7
# 3              0          1000    13500           'admin'           0.7
# 4              0          1000    13500           'admin'           0.7
# ...          ...           ...      ...               ...           ...
# 599995         0          1000    13500           'admin'           0.7
# 599996         0          1000    13500           'admin'           0.7
# 599997         0          1000    13500           'admin'           0.7
# 599998         0          1000    13500           'admin'           0.7
# 599999         0          1000    13500           'admin'           0.7
#
#                      group_member_fee_list  ... unique_pickup_points_toggle  \
# 0       [{'shipping_fee_no_surge': 13500.0  ...                       False
# 1       [{'shipping_fee_no_surge': 13500.0  ...                       False
# 2       [{'shipping_fee_no_surge': 13500.0  ...                       False
# 3       [{'shipping_fee_no_surge': 13500.0  ...                       False
# 4       [{'shipping_fee_no_surge': 13500.0  ...                       False
# ...                                    ...  ...                         ...
# 599995  [{'shipping_fee_no_surge': 13500.0  ...                       False
# 599996  [{'shipping_fee_no_surge': 13500.0  ...                       False
# 599997  [{'shipping_fee_no_surge': 13500.0  ...                       False
# 599998  [{'shipping_fee_no_surge': 13500.0  ...                       False
# 599999  [{'shipping_fee_no_surge': 13500.0  ...                       False
#
#         original_dropoff_points hub_stack_fee  pickup_points  \
# 0                             2     13500.000              2
# 1                             2     13500.000              2
# 2                             2     14227.500              2
# 3                             2     22403.250              2
# 4                             2     13500.000              2
# ...                         ...           ...            ...
# 599995                        2     15727.125              2
# 599996                        2     13500.000              2
# 599997                        2     17831.250              2
# 599998                        2     13500.000              2
# 599999                        2     13500.000              2
#
#         package_decrease_original_fee_replace  discount_fee  \
# 0                                       False       18900.0
# 1                                       False       18900.0
# 2                                       False       18900.0
# 3                                       False       18900.0
# 4                                       False       18900.0
# ...                                       ...           ...
# 599995                                  False       18900.0
# 599996                                  False       18900.0
# 599997                                  False       18900.0
# 599998                                  False       18900.0
# 599999                                  False       18900.0
#
#         unique_dropoff_points_toggle    original_delivery_info  \
# 0                              False  {'shipping_fee': 13500.0
# 1                              False  {'shipping_fee': 13500.0
# 2                              False  {'shipping_fee': 13500.0
# 3                              False  {'shipping_fee': 13500.0
# 4                              False  {'shipping_fee': 27000.0
# ...                              ...                       ...
# 599995                         False  {'shipping_fee': 27000.0
# 599996                         False  {'shipping_fee': 27000.0
# 599997                         False  {'shipping_fee': 27000.0
# 599998                         False  {'shipping_fee': 13500.0
# 599999                         False  {'shipping_fee': 13500.0
#
#            delivery_order_ids hub_extra_fee
# 0                 [516397459]          2000
# 1                 [516905430]          2000
# 2                 [516903149]          2000
# 3                 [516398043]          2000
# 4       [516391407,516394276]          2000
# ...                       ...           ...
# 599995  [515607778,515608664]          2000
# 599996  [515607312,515608093]          2000
# 599997  [515609346,515609757]          2000
# 599998            [515809831]          2000
# 599999            [515160163]          2000
#
# [600000 rows x 33 columns]
