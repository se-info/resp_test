# %% [markdown]
# Source: https://github.com/mwaskom/seaborn-data (see https://en.wikipedia.org/wiki/Anscombe%27s_quartet)
#
# 1. longitude: A measure of how far west a house is; a higher value is farther west
#
# 2. latitude: A measure of how far north a house is; a higher value is farther north
#
# 3. housingMedianAge: Median age of a house within a block; a lower number is a newer building
#
# 4. totalRooms: Total number of rooms within a block
#
# 5. totalBedrooms: Total number of bedrooms within a block
#
# 6. population: Total number of people residing within a block
#
# 7. households: Total number of households, a group of people residing within a home unit, for a block
#
# 8. medianIncome: Median income for households within a block of houses (measured in tens of thousands of US Dollars)
#
# 9. medianHouseValue: Median house value for households within a block (measured in US Dollars)
#
# 10. oceanProximity: Location of the house w.r.t ocean/sea

# %%
# !pip install --extra-index-url https://pypi-nightly.tensorflow.org/simple tensorflow-data-validation
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi-nightly.tensorflow.org/simple
# Collecting tensorflow-data-validation
#   Downloading tensorflow_data_validation-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 74.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow-data-validation) (1.4.0)
# Collecting apache-beam[gcp]<3,>=2.47 (from tensorflow-data-validation)
#   Downloading apache_beam-2.52.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 74.2 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-data-validation) (1.3.2)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-data-validation) (1.23.5)
# Requirement already satisfied: pandas<2,>=1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-data-validation) (1.5.3)
# Requirement already satisfied: protobuf<5,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-data-validation) (3.20.3)
# Collecting pyarrow<11,>=10 (from tensorflow-data-validation)
#   Downloading pyarrow-10.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 17.2 MB/s eta 0:00:00
# Collecting pyfarmhash<0.4,>=0.2.2 (from tensorflow-data-validation)
#   Downloading pyfarmhash-0.3.2.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.9/99.9 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six<2,>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow-data-validation) (1.16.0)
# Requirement already satisfied: tensorflow<3,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow-data-validation) (2.14.0)
# Requirement already satisfied: tensorflow-metadata<1.15,>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-data-validation) (1.14.0)
# Collecting tfx-bsl<1.15,>=1.14.0 (from tensorflow-data-validation)
#   Downloading tfx_bsl-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 69.9 MB/s eta 0:00:00
# Collecting crcmod<2.0,>=1.7 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting orjson<4,>=3.9.7 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 12.1 MB/s eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 21.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.2.1)
# Collecting fastavro<2,>=0.23.6 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading fastavro-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 97.1 MB/s eta 0:00:00
# Collecting fasteners<1.0,>=0.3 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (1.59.3)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading hdfs-2.7.3.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (0.22.0)
# Collecting js2py<1,>=0.74 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.5 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (4.19.2)
# Collecting objsize<0.7.0,>=0.6.1 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (23.2)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading pymongo-4.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 51.8 MB/s eta 0:00:00
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (1.22.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2023.3.post1)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2023.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (4.5.0)
# Collecting zstandard<1,>=0.18.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 15.2 MB/s eta 0:00:00
# Collecting pyarrow-hotfix<1 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: cachetools<6,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (5.3.2)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.11.1)
# Collecting google-apitools<0.5.32,>=0.5.31 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google-apitools-0.5.31.tar.gz (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 kB 20.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: google-auth<3,>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.17.3)
# Requirement already satisfied: google-auth-httplib2<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (0.1.1)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.15.2)
# Collecting google-cloud-pubsub<3,>=2.1.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google_cloud_pubsub-2.18.4-py2.py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 28.2 MB/s eta 0:00:00
# Collecting google-cloud-pubsublite<2,>=1.2.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google_cloud_pubsublite-1.8.3-py2.py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.1/288.1 kB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (3.12.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.23.0)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.3.3)
# Collecting google-cloud-bigtable<3,>=2.19.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google_cloud_bigtable-2.21.0-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.0/293.0 kB 33.0 MB/s eta 0:00:00
# Collecting google-cloud-spanner<4,>=3.0.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google_cloud_spanner-3.40.1-py2.py3-none-any.whl (332 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.9/332.9 kB 40.5 MB/s eta 0:00:00
# Collecting google-cloud-dlp<4,>=3.0.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google_cloud_dlp-3.13.0-py2.py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.9.1)
# Collecting google-cloud-videointelligence<3,>=2.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google_cloud_videointelligence-2.11.4-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.5/229.5 kB 26.5 MB/s eta 0:00:00
# Collecting google-cloud-vision<4,>=2 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google_cloud_vision-3.4.5-py2.py3-none-any.whl (444 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.1/444.1 kB 42.4 MB/s eta 0:00:00
# Collecting google-cloud-recommendations-ai<0.11.0,>=0.1.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google_cloud_recommendations_ai-0.10.5-py2.py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 21.9 MB/s eta 0:00:00
# Collecting google-cloud-aiplatform<2.0,>=1.26.0 (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading google_cloud_aiplatform-1.36.4-py2.py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 62.7 MB/s eta 0:00:00
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (0.34.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-data-validation) (2.14.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata<1.15,>=1.14.0->tensorflow-data-validation) (1.61.0)
# Collecting google-api-python-client<2,>=1.7.11 (from tfx-bsl<1.15,>=1.14.0->tensorflow-data-validation)
#   Downloading google_api_python_client-1.12.11-py2.py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 8.3 MB/s eta 0:00:00
# Collecting tensorflow-serving-api<3,>=2.13.0 (from tfx-bsl<1.15,>=1.14.0->tensorflow-data-validation)
#   Downloading tensorflow_serving_api-2.14.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<3,>=2.13->tensorflow-data-validation) (0.42.0)
# Collecting uritemplate<4dev,>=3.0.0 (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.15,>=1.14.0->tensorflow-data-validation)
#   Downloading uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: oauth2client>=1.4.12 in /usr/local/lib/python3.10/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (4.9)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.8.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (1.10.4)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.0.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.6.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (0.12.7)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (1.48.2)
# Collecting overrides<7.0.0,>=6.0.1 (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading overrides-6.5.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (0.4.4)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (3.1.1)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (5.2)
# Collecting pyjsparser>=2.5.1 (from js2py<1,>=0.74->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (0.13.2)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 39.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (2023.11.17)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation) (3.0.1)
# Collecting tensorflow<3,>=2.13 (from tensorflow-data-validation)
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 1.8 MB/s eta 0:00:00
# Collecting tensorboard<2.16,>=2.15 (from tensorflow<3,>=2.13->tensorflow-data-validation)
#   Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 4.8 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow<3,>=2.13->tensorflow-data-validation)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 4.0 MB/s eta 0:00:00
# Collecting keras<2.16,>=2.15.0 (from tensorflow<3,>=2.13->tensorflow-data-validation)
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation) (1.3.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (1.5.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation) (3.2.2)
# Building wheels for collected packages: pyfarmhash, crcmod, dill, google-apitools, hdfs, pyjsparser, docopt
#   Building wheel for pyfarmhash (setup.py) ... done
#   Created wheel for pyfarmhash: filename=pyfarmhash-0.3.2-cp310-cp310-linux_x86_64.whl size=88657 sha256=dcbf7d4d5c5e6c286ce99c933fa8f93ed6bc28eab8f60d818abe4c2f1fcc67cc
#   Stored in directory: /root/.cache/pip/wheels/e0/08/da/f66b1f3258fe3f1e767b2136c5444dbfa9fa3f7944cc5e1983
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31407 sha256=54d0217a27b7ab495e221e88a9d6b2c19f6786cc5302d52229535b6ab6400b18
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78540 sha256=02fa79954e8429618e1977e71f7cb1853b24f06dc434ae42872b3d0c885eb4cc
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for google-apitools (setup.py) ... done
#   Created wheel for google-apitools: filename=google_apitools-0.5.31-py3-none-any.whl size=131015 sha256=4c81ff5901b6683a9c0a1f3dc1e0be2ee722427aa05a7dc8c033760be02a3293
#   Stored in directory: /root/.cache/pip/wheels/04/b7/e0/9712f8c23a5da3d9d16fb88216b897bf60e85b12f5470f26ee
#   Building wheel for hdfs (setup.py) ... done
#   Created wheel for hdfs: filename=hdfs-2.7.3-py3-none-any.whl size=34325 sha256=32b752d64abd82609c2c45438bb167b09286a1e68d8ca8a25c20060a0bb0da10
#   Stored in directory: /root/.cache/pip/wheels/e5/8d/b6/99c1c0a3ac5788c866b0ecd3f48b0134a5910e6ed26011800b
#   Building wheel for pyjsparser (setup.py) ... done
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=25984 sha256=777bf0ae8e211ff2205302decd4c14d629333d0fb3cef95e7b0331f9878e6b61
#   Stored in directory: /root/.cache/pip/wheels/5e/81/26/5956478df303e2bf5a85a5df595bb307bd25948a4bab69f7c7
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=5a147b2bba448cc94ea631fb68919af464b21d5386d379fbb5d8626442165904
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built pyfarmhash crcmod dill google-apitools hdfs pyjsparser docopt
# Installing collected packages: pyjsparser, pyfarmhash, docopt, crcmod, zstandard, uritemplate, tensorflow-estimator, pyarrow-hotfix, pyarrow, overrides, orjson, objsize, keras, js2py, fasteners, fastavro, dnspython, dill, pymongo, hdfs, google-apitools, tensorboard, google-api-python-client, apache-beam, tensorflow, google-cloud-vision, google-cloud-videointelligence, google-cloud-spanner, google-cloud-recommendations-ai, google-cloud-pubsub, google-cloud-dlp, google-cloud-bigtable, tensorflow-serving-api, google-cloud-pubsublite, google-cloud-aiplatform, tfx-bsl, tensorflow-data-validation
#   Attempting uninstall: uritemplate
#     Found existing installation: uritemplate 4.1.1
#     Uninstalling uritemplate-4.1.1:
#       Successfully uninstalled uritemplate-4.1.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 9.0.0
#     Uninstalling pyarrow-9.0.0:
#       Successfully uninstalled pyarrow-9.0.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.84.0
#     Uninstalling google-api-python-client-2.84.0:
#       Successfully uninstalled google-api-python-client-2.84.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-gbq 0.17.9 requires pyarrow<10.0dev,>=3.0.0, but you have pyarrow 10.0.1 which is incompatible.
# Successfully installed apache-beam-2.52.0 crcmod-1.7 dill-0.3.1.1 dnspython-2.4.2 docopt-0.6.2 fastavro-1.9.0 fasteners-0.19 google-api-python-client-1.12.11 google-apitools-0.5.31 google-cloud-aiplatform-1.36.4 google-cloud-bigtable-2.21.0 google-cloud-dlp-3.13.0 google-cloud-pubsub-2.18.4 google-cloud-pubsublite-1.8.3 google-cloud-recommendations-ai-0.10.5 google-cloud-spanner-3.40.1 google-cloud-videointelligence-2.11.4 google-cloud-vision-3.4.5 hdfs-2.7.3 js2py-0.74 keras-2.15.0 objsize-0.6.1 orjson-3.9.10 overrides-6.5.0 pyarrow-10.0.1 pyarrow-hotfix-0.6 pyfarmhash-0.3.2 pyjsparser-2.7.1 pymongo-4.6.1 tensorboard-2.15.1 tensorflow-2.15.0 tensorflow-data-validation-1.14.0 tensorflow-estimator-2.15.0 tensorflow-serving-api-2.14.1 tfx-bsl-1.14.0 uritemplate-3.0.1 zstandard-0.22.0

# %%
# import tensorflow as tf
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split


from tensorflow_metadata.proto.v0 import schema_pb2

# print('TFDV Version: {}'.format(tfdv.__version__))
print('Tensorflow Version: {}'.format(tf.__version__))
# Out:
# Tensorflow Version: 2.15.0

# %%
import tensorflow_data_validation as tfdv

# %%
import pandas as pd

# %%
train_df = pd.read_csv('/content/sample_data/california_housing_train.csv')
val_df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %% [markdown]
# ## Data Analysis

# %%
train_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
train_stats = tfdv.generate_statistics_from_dataframe(train_df)
tfdv.visualize_statistics(train_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
X_train = train_df.drop('median_house_value', axis = 1)
y_train = train_df['median_house_value']

# %% [markdown]
# Normalizing `longitude`, `latitude`, `total_rooms`, `total_bedrooms`, `population`, `households`

# %%
import pandas as pd
from sklearn import preprocessing

from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

column_names_to_normalize = ['longitude', 'latitude', 'total_rooms', 'total_bedrooms', 'population', 'households']
x = X_train[column_names_to_normalize].values
x_scaled = min_max_scaler.fit_transform(x)
normalized_features = pd.DataFrame(x_scaled, columns=column_names_to_normalize, index = X_train.index)
X_train[column_names_to_normalize] = normalized_features

# %% [markdown]
# Standardizing `housing_median_age`, `latitude`, `total_rooms`, `total_bedrooms`, `population`, `households`

# %%
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()

column_names_to_standardize = ['housing_median_age', 'median_income']
x = X_train[column_names_to_standardize].values
x_scaled = standard_scaler.fit_transform(x)

standardized_features = pd.DataFrame(x_scaled, columns=column_names_to_standardize, index = X_train.index)
X_train[column_names_to_standardize] = standardized_features

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       1.000000  0.175345                15.0     0.147885        0.198945
# 1       0.984064  0.197662                19.0     0.201608        0.294848
# 2       0.975100  0.122210                17.0     0.018927        0.026847
# 3       0.974104  0.116897                14.0     0.039515        0.052142
# 4       0.974104  0.109458                20.0     0.038276        0.050435
# ...          ...       ...                 ...          ...             ...
# 16995   0.008964  0.854410                52.0     0.058389        0.060987
# 16996   0.007968  0.866100                36.0     0.061869        0.081782
# 16997   0.004980  0.988310                17.0     0.070515        0.082247
# 16998   0.004980  0.984060                19.0     0.070384        0.085506
# 16999   0.000000  0.850159                52.0     0.047924        0.046400
#
#        population  households  median_income
# 0        0.028364    0.077454         1.4936
# 1        0.031559    0.075974         1.8200
# 2        0.009249    0.019076         1.6509
# 3        0.014350    0.037000         3.1917
# 4        0.017405    0.042921         1.9250
# ...           ...         ...            ...
# 16995    0.025337    0.060516         2.3571
# 16996    0.033381    0.076303         2.5179
# 16997    0.034782    0.074823         3.0313
# 16998    0.036296    0.078441         1.9797
# 16999    0.022506    0.044236         3.0147
#
# [17000 rows x 8 columns]

# %%
X_train.shape
# Out:
# (17000, 9)

# %%
train_stats = tfdv.generate_statistics_from_dataframe(X_train)
# tfdv.visualize_statistics(train_stats)

# %%
import numpy as np
m, n = X_train.shape
ones = np.ones_like((m, 1))
ones.shape
# Out:
# (2,)

# %%
m
# Out:
# 17000

# %%
import numpy as np
m, n = X_train.shape
ones = np.ones((m, 1))
X_train = np.concatenate((X_train, ones), axis=1)

# %%
# X: (17000, 9)
# W: (9, 1)

# %%
X_train.shape
# Out:
# (17000, 9)

# %%
theta = np.random.normal(size=X_train.shape[1]).reshape((X_train.shape[1], 1))

X_train.dot(theta).shape

y_train = y_train.values.reshape(-1, 1)

# %%
theta
# Out:
# array([[-0.49271283],
#        [ 0.44551726],
#        [-0.54568178],
#        [ 2.01505048],
#        [ 0.72854352],
#        [ 0.30179488],
#        [-0.8293782 ],
#        [ 0.5635002 ],
#        [-0.72414667]])

# %%
learning_rate = 0.5

def hypo(X, theta):
  return X.dot(theta)

def gradient(X, y, theta, m):
  gradient = 1/m * X.T.dot(hypo(X, theta) - y) # (2 x 1)
  return gradient

def loss(X, y, theta, m):
  return 1/(2 *m)* np.sum((hypo(X, theta) - y)**2)

epochs = 20000


for i in range(epochs):
  grad = gradient(X_train, y_train, theta, m)
  theta = theta - learning_rate * grad
  if (i+1) % 1000 == 0:
    print('Loss is: {}'.format(loss(X_train, y_train, theta, m)))
# Out:
# <ipython-input-20-11044b7af61d>:18: RuntimeWarning: invalid value encountered in subtract
#   theta = theta - learning_rate * grad
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan
# Loss is: nan

# %%
theta
# Out:
# array([[ -433283.21256995],
#        [ -402839.40129082],
#        [   14568.78393649],
#        [ -299138.47876517],
#        [  685196.15234926],
#        [-1149864.22961332],
#        [  231011.40093028],
#        [   77073.03690252],
#        [  536557.22731731]])

# %%
from sklearn.linear_model import LinearRegression
linearRegressor = LinearRegression().fit(X_train,y_train)
linearRegressor
# Out:
# LinearRegression()

# %%
linearRegressor.coef_
# Out:
# array([[-4.33121958e+05, -4.03930584e+05,  1.15069493e+03,
#         -3.17828960e+05,  7.58127210e+05, -1.37324090e+06,
#          2.76296332e+05,  4.05070684e+04,  0.00000000e+00]])
